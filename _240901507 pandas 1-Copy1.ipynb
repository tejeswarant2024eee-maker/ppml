# %%
import pandas as pd
#EmptyDataFrame
df=pd.DataFrame()
print (df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
emp=pd.Series(['parker','john','smith','william'])
id=pd.Series([102,107,109,114])
frame={'Emp':emp,'ID':id}
result=pd.DataFrame(frame)
print("\nseries to data frame\n")
print(result)
# Out:
# series to data frame
#
#        Emp   ID
# 0   parker  102
# 1     john  107
# 2    smith  109
# 3  william  114

# %%
print("\n Extracting one coloumn:\n")
print(result['Emp'])
# Out:
#  Extracting one coloumn:
#
# 0     parker
# 1       john
# 2      smith
# 3    william
# Name: Emp, dtype: object

# %%
print("\nDeleting one coloumn:\n")
delresult['Age']
print(result)
# Out:
# Deleting one coloumn:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 print("\nDeleting one coloumn:\n")
# ----> 2 delresult['Age']
#       3 print(result)
#
# NameError: name 'delresult' is not defined

# %%
print("\nExtracting the third row:\n")
print(result.loc[2])
# Out:
# Extracting the third row:
#
# Emp    smith
# ID       109
# Name: 2, dtype: object

# %%
print("\nSilice rows:\n",result[1:3])
# Out:
# Silice rows:
#       Emp   ID
# 1   john  107
# 2  smith  109

# %%
d2=pd.DataFrame([['Dale',123],['Mark',143]],columns=['Emp','ID'])
print("\nAdding new row values:\n",result.append(d2))
# Out:
# Adding new row values:
#         Emp   ID
# 0   parker  102
# 1     john  107
# 2    smith  109
# 3  william  114
# 0     Dale  123
# 1     Mark  143
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17820\1753680200.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   print("\nAdding new row values:\n",result.append(d2))

# %%
print("\nDeleting particular row:\n",result.drop(1))
# Out:
# Deleting particular row:
#         Emp   ID
# 0   parker  102
# 2    smith  109
# 3  william  114
